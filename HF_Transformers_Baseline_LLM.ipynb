# %% [markdown]
# ### 배성수님
# 허깅페이스는 챗봇 회사임

# %%
import transformers

# %%
transformers.__version__
# Out:
# '4.38.2'

# %%
from transformers import pipeline

# %%
generate= pipeline("text-generation")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 6c0e608 (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
generate("What is natural language processing?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'What is natural language processing?\n\nNatural language processing is what happens when we have a task task you may have in your mind. If you have the same task for a few minutes it will become much easier to explain.\n\nHowever there are'}]

# %%
classifier = pipeline("sentiment-analysis", model = "hun3359/klue-bert-base-sentiment")
# Out:
# config.json:   0%|          | 0.00/3.67k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/367 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
classifier("오늘은 주식이 오를까?")
# Out:
# [{'label': '걱정스러운', 'score': 0.15089015662670135}]

# %%
classifier.model
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
# ...

# %% [markdown]
# 파이프라인: 토크나이징 -> 모델 -> 후처리

# %%
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
classifier('sleepy')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9993759989738464}]

# %%
raw_text = "This course is amazing"

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
tokenizer.tokenize(raw_text)
# Out:
# ['this', 'course', 'is', 'amazing']

# %%
tokenizer.tokenize(raw_text)
# Out:
# ['this', 'course', 'is', 'amazing']

# %%
inputs = tokenizer(raw_text)

# %%
inputs
# Out:
# {'input_ids': [101, 2023, 2607, 2003, 6429, 102], 'attention_mask': [1, 1, 1, 1, 1, 1]}

# %%
from transformers import AutoModel

# %%
model = AutoModel.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
model(**inputs)
# Out:
# BaseModelOutput(last_hidden_state=tensor([[[ 0.7329,  0.1707,  0.0793,  ...,  0.4191,  0.8737, -0.4566],
#          [ 0.8505,  0.1748,  0.0141,  ...,  0.3580,  0.8751, -0.3632],
#          [ 0.9367,  0.1603,  0.1223,  ...,  0.3447,  0.7271, -0.3963],
#          [ 0.8822,  0.1991,  0.0914,  ...,  0.4155,  0.8312, -0.3368],
#          [ 0.8828,  0.2775,  0.1110,  ...,  0.4801,  0.8287, -0.5239],
#          [ 1.0449,  0.1616,  0.7466,  ...,  0.4432,  0.6366, -0.7913]]],
#        grad_fn=<NativeLayerNormBackward0>), hidden_states=None, attentions=None)

# %%
inputs = tokenizer(raw_text, return_tensors="pt")

# %%
inputs
# Out:
# {'input_ids': tensor([[ 101, 2023, 2607, 2003, 6429,  102]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}

# %%
outputs = model(**inputs)
